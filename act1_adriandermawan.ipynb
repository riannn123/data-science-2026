# %% [markdown]
# ## SEL 1: Output Sederhana

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %% [markdown]
# ## SEL 2: Variabel & tipe data

# %%
nama = "Adrian Dermawan Budyanto"
angkatan = "2025"
print(f"Hello, {nama} angkatan {angkatan}!")
# Out:
# Hello, Adrian Dermawan Budyanto angkatan 2025!

# %% [markdown]
# ## SEL 3: Liat & perulangan

# %%
tools = ["Python","Colab","Jupyter","Github"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. Github

# %% [markdown]
# ## SELL 4: Fungsi Python

# %%
def perkenalan (nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Adrian", "Informatika", 2025))
# Out:
# Adrian | Informatika | 2025
